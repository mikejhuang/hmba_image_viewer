# %%
import psycopg2
import pandas as pd
import sqlalchemy
import os

# %%
lims_user = "atlasreader"
lims_pwd = "atlasro"
lims_alias = "limsdb3"

engine = sqlalchemy.create_engine(
    f"postgresql+psycopg2://{lims_user}:{lims_pwd}@{lims_alias}/lims2")

# %%
query = '''
        select sp.id as specimen_id,
        sp.name as specimen_name,
        t.name as treatment_name,
        iser.id as image_series_id,
        sc.resolution as image_resolution,
        img.id as image_id,
        img.zoom,
        img.zoom_tiers,
        sl.storage_directory,
        si.*
        from sub_images si
        join image_series iser on si.image_series_id = iser.id
        join run_groups rg on  iser.run_group_id = rg.id
        join treatments t on t.id = rg.treatment_id
        join images img on img.id = si.image_id
        join slides sl on sl.id = img.slide_id
        join scans sc ON sc.slide_id = sl.id
        join specimens sp on iser.specimen_id = sp.id
        where sp.name = 'QM23.50.001.CX.44.01.HE'
        '''
res = pd.read_sql(query,con=engine)
res
# Out:
#    specimen_id            specimen_name treatment_name  image_series_id  \
# 0   1304634597  QM23.50.001.CX.44.01.HE            H&E       1304649496
# 1   1304634597  QM23.50.001.CX.44.01.HE            H&E       1304649496
#
#    image_resolution    image_id            zoom  zoom_tiers  \
# 0              0.55  1304649495  2310184402.aff           8
# 1              0.55  1304649498  2310184401.aff           8
#
#                                    storage_directory          id  ...  col  \
# 0  /allen/programs/celltypes/production/nhpcellty...  1304649497  ...    0
# 1  /allen/programs/celltypes/production/nhpcellty...  1304649499  ...    0
#
#    specimen_tissue_index  closest_nissl_sub_image_id  area  \
# 0                      2                        None  None
# 1                      1                        None  None
#
#    image_series_sub_image_index  alignment2d_id sub_image_type_id  \
# 0                             2            None                 1
# ...

# %%
query = '''
        select img.*
        from sub_images si
        join image_series iser on si.image_series_id = iser.id
        join run_groups rg on  iser.run_group_id = rg.id
        join treatments t on t.id = rg.treatment_id
        join images img on img.id = si.image_id
        join slides sl on sl.id = img.slide_id
        join scans sc ON sc.slide_id = sl.id
        join specimens sp on iser.specimen_id = sp.id
        where sp.name = 'QM23.50.001.CX.44.01.HE'
        '''
res = pd.read_sql(query,con=engine)
res
# Out:
#            id             jp2            zoom                 created_at  \
# 0  1304649495  2310184402.jp2  2310184402.aff 2023-10-18 22:06:22.467186
# 1  1304649498  2310184401.jp2  2310184401.aff 2023-10-18 22:06:22.531408
#
#                   updated_at qc_date    slide_id  width  height  \
# 0 2023-10-23 23:12:00.675588    None  1304634680  14912   28848
# 1 2023-10-23 23:06:54.464835    None  1304634679  16352   27632
#
#    image_type_id parent_id  position specimen_id jp2_md5sum  flip_id  \
# 0              1      None         1        None       None        4
# 1              1      None         1        None       None        4
#
#    zoom_tiers archive_dir zoom_archive_dir treatment_id
# 0           8        None             None         None
# 1           8        None             None         None

# %%
query = '''
        select sc.*,
        img.id as image_id_imgtable
        from sub_images si
        join image_series iser on si.image_series_id = iser.id
        join run_groups rg on  iser.run_group_id = rg.id
        join treatments t on t.id = rg.treatment_id
        join images img on img.id = si.image_id
        join slides sl on sl.id = img.slide_id
        join scans sc ON sc.slide_id = sl.id
        join specimens sp on iser.specimen_id = sp.id
        where sp.name = 'QM23.50.001.CX.44.01.HE'
        '''
res = pd.read_sql(query,con=engine)
res
# Out:
#            id                                               path  \
# 0  1305788963  /allen/programs/celltypes/production/incoming/...
# 1  1305787725  /allen/programs/celltypes/production/incoming/...
#
#                  archived_at  superseded    slide_id  scanner_id  \
# 0 2023-11-01 21:41:40.991515       False  1304634680  1049455195
# 1 2023-11-01 21:40:37.964310       False  1304634679  1049455195
#
#                   created_at                 updated_at image_id  \
# 0 2023-10-23 22:50:38.689833 2023-11-01 21:41:40.992176     None
# 1 2023-10-23 22:45:40.206490 2023-11-01 21:40:37.965090     None
#
#                state  resolution  bits_per_component  number_of_components  \
# 0  archived_to_cloud        0.55                   8                     3
# 1  archived_to_cloud        0.55                   8                     3
#
#   rotation offset_x offset_y treatment_id  project_id  specimen_id  \
# 0     None     None     None         None  1214247498   1304634597
# ...

# %%
query = '''
        select si.*,
        img.id as image_id_imgtable
        from sub_images si
        join image_series iser on si.image_series_id = iser.id
        join run_groups rg on  iser.run_group_id = rg.id
        join treatments t on t.id = rg.treatment_id
        join images img on img.id = si.image_id
        join slides sl on sl.id = img.slide_id
        join scans sc ON sc.slide_id = sl.id
        join specimens sp on iser.specimen_id = sp.id
        where sp.name = 'QM23.50.001.CX.44.01.HE'
        '''
res = pd.read_sql(query,con=engine)
res
# Out:
#            id    image_id  row  x  y  width  height  \
# 0  1304649497  1304649495    0  1  1  14910   28846
# 1  1304649499  1304649498    0  1  1  16350   27630
#
#                   created_at                 updated_at  image_series_id  ...  \
# 0 2023-10-18 22:06:22.512701 2023-10-23 23:16:34.926489       1304649496  ...
# 1 2023-10-18 22:06:22.562639 2023-10-23 23:11:49.734936       1304649496  ...
#
#    specimen_tissue_index  closest_nissl_sub_image_id  area  \
# 0                      2                        None  None
# 1                      1                        None  None
#
#   image_series_sub_image_index alignment2d_id sub_image_type_id  \
# 0                            2           None                 1
# 1                            1           None                 1
#
#    bounding_box_index  lims1_id svg_upload_msg image_id_imgtable
# 0                   1      None           None        1304649495
# ...

# %%
res.path[0]
# Out:
# '/allen/programs/celltypes/production/incoming/nhpcelltypes/macaqueatlas/2310184402.scn'

# %%
#sp_id = '1304634597'
sp_id = '1297061003'
query = f'''
        select sc.*
        from specimens sp
        join images img on img.specimen_id = sp.id
        join scans sc on sc.image_id = img.id
        where sp.id = {sp_id}
        '''
res = pd.read_sql(query,con=engine)
res
# Out:
#            id                                               path archived_at  \
# 0  1316183762  /allen/programs/celltypes/production/nhpcellty...        None
# 1  1316183651  /allen/programs/celltypes/production/nhpcellty...        None
# 2  1312798660  /allen/programs/celltypes/production/nhpcellty...        None
# 3  1312798617  /allen/programs/celltypes/production/nhpcellty...        None
#
#    superseded slide_id  scanner_id                 created_at  \
# 0       False     None           2 2023-12-07 19:21:10.103378
# 1       False     None           2 2023-12-07 19:20:55.485294
# 2       False     None           2 2023-11-22 17:50:56.075369
# 3       False     None           2 2023-11-22 17:50:51.195584
#
#                   updated_at    image_id           state  resolution  \
# 0 2023-12-07 19:21:10.103378  1316183760  do_not_archive        30.3
# 1 2023-12-07 19:20:55.485294  1316183649  do_not_archive        30.3
# ...

# %%
res.path[0]
# Out:
# '/allen/programs/celltypes/production/nhpcelltypes/macaqueatlas/prod0/specimen_1297061003/'

# %%
sp_id = '1297061003' # blockface image
#sp_id = '1304634597' # HE image
query = f'''
        select img.zoom as zoom,
        img.jp2 as jp2,
        sp.storage_directory as storage_directory,
        sc.resolution as resolution
        from specimens sp
        join images img on img.specimen_id = sp.id
        join scans sc on sc.image_id = img.id
        where sp.id = {sp_id}
        '''
res = pd.read_sql(query,con=engine)
res
# Out:
#                                           zoom  \
# 0  4_8719_1297061003_blockface_images-0001.aff
# 1  3_8718_1297061003_blockface_images-0000.aff
# 2       2_1297061003_blockface_images-0001.aff
# 3       1_1297061003_blockface_images-0000.aff
#
#                                            jp2  \
# 0  4_8719_1297061003_blockface_images-0001.tif
# 1  3_8718_1297061003_blockface_images-0000.tif
# 2       2_1297061003_blockface_images-0001.tif
# 3       1_1297061003_blockface_images-0000.tif
#
#                                    storage_directory  resolution
# 0  /allen/programs/celltypes/production/nhpcellty...        30.3
# 1  /allen/programs/celltypes/production/nhpcellty...        30.3
# 2  /allen/programs/celltypes/production/nhpcellty...        12.0
# 3  /allen/programs/celltypes/production/nhpcellty...        12.0

# %%
row = res.iloc[0]
print(os.path.join(row.storage_directory, row.jp2))
# Out:
# /allen/programs/celltypes/production/nhpcelltypes/macaqueatlas/prod0/specimen_1289945666/1_1289945666_blockface_images-0000.tif

# %%
res.path[0]
# Out:
# '/allen/programs/celltypes/production/nhpcelltypes/macaqueatlas/prod0/specimen_1289945666/'

# %%
query = '''
        select sp.id as specimen_id,
        sp.name as specimen_name,
        t.name as treatment_name,
        iser.id as image_series_id,
        sc.resolution as image_resolution,
        img.zoom,
        img.zoom_tiers,
        si.*
        from sub_images si
        join image_series iser on si.image_series_id = iser.id
        join run_groups rg on  iser.run_group_id = rg.id
        join treatments t on t.id = rg.treatment_id
        join images img on img.id = si.image_id
        join scans sc ON sc.image_id = img.id
        join specimens sp on iser.specimen_id = sp.id
        where sp.name = 'QM23.50.001.CX.44.01.HE'
        '''
res = pd.read_sql(query,con=engine)
res
# Out:
# Empty DataFrame
# Columns: [specimen_id, specimen_name, treatment_name, image_series_id, image_resolution, zoom, zoom_tiers, id, image_id, row, x, y, width, height, created_at, updated_at, image_series_id, failed, specimen_id, sub_image_qcstate_reason_id, qc_date, expression, structure_id, col, specimen_tissue_index, closest_nissl_sub_image_id, area, image_series_sub_image_index, alignment2d_id, sub_image_type_id, bounding_box_index, lims1_id, svg_upload_msg]
# Index: []
#
# [0 rows x 33 columns]

# %%
from glob import glob
import re
files = glob('/allen/programs/celltypes/workgroups/rnaseqanalysis/mFISH/merfish_qc/macaque/mfishmerscopemacaqueatlas/qc_images/*_dapi.png')
files = [file.split('/')[-1] for file in files]
filtered_files = [f for f in files if re.match(r'\d+_dapi\.png', f)]
barcodes = [file.split('_')[0] for file in filtered_files]

specimen_barcode_dict = {}
for barcode in barcodes:
    query = '''
            select sp.id as specimen_id,
            sp.name as specimen_name,
            sp.barcode as barcode
            from specimens sp
            where sp.barcode = '%s'
            ''' % barcode
    res = pd.read_sql(query,con=engine)
    if len(res) == 0:
        print("No LIMS2 entry found")
    elif(len(res) > 1):
        print("More than one entry found")
    else:
        specimen_name = res['specimen_name'].iloc[0]
        specimen_barcode_dict[specimen_name] = barcode
# Out:
# 1291812132
# QM23.50.001.CX.43.02.11.02
# 1291812195
# QM23.50.001.CX.43.02.07.03
# 1291820940
# QM23.50.001.CX.46.01.01.02
# 1291815690
# QM23.50.001.CX.45.03.05.02
# 1291813673
# QM23.50.001.CX.44.04.05.03
# 1291814154
# QM23.50.001.CX.44.01.01.02
# 1291820837
# QM23.50.001.CX.46.01.07.02
# 1291816092
# QM23.50.001.CX.45.01.01.02
# 1291814069
# QM23.50.001.CX.44.01.07.02
# 1291815525
# QM23.50.001.CX.45.04.05.03
# 1291812368
# QM23.50.001.CX.43.01.09.03
# 1291820518
# QM23.50.001.CX.46.03.01.03
# 1291813725
# No LIMS2 entry found
# 1291813932
# QM23.50.001.CX.44.02.07.03
# 1291820638
# QM23.50.001.CX.46.02.05.02
# 1291814126
# QM23.50.001.CX.44.01.03.02
# 1291820711
# QM23.50.001.CX.46.02.01.03
# 1291813960
# QM23.50.001.CX.44.02.05.03
# 1291810584
# QM23.50.001.CX.42.02.05.03
# 1291812447
# QM23.50.001.CX.43.01.03.02
# 1291812161
# QM23.50.001.CX.43.02.09.02
# 1291812074
# QM23.50.001.CX.43.03.01.02
# 1291816006
# QM23.50.001.CX.45.01.07.02
# 1291811960
# ...

# %%
from pathlib import Path
import shutil

sp_names = list(specimen_barcode_dict.keys())
cache_dir = Path('/allen/aibs/informatics/mike.huang/hmba/QM23.50.001.CX.44.DAPI')
# create cache_dir if it doesn't exist
cache_dir.mkdir(parents=True, exist_ok=True)

source_dir = Path('/allen/programs/celltypes/workgroups/rnaseqanalysis/mFISH/merfish_qc/macaque/mfishmerscopemacaqueatlas/qc_images/')

for i in range(1,5):
    cx44 = [name for name in sp_names if name.startswith(f'QM23.50.001.CX.44.0{i}')]
    print(cx44)
    for sp_name in cx44:
        barcode = specimen_barcode_dict[sp_name]
        filename = f'{barcode}_dapi.png'
        out_filename = f'{sp_name}.png'
        shutil.copy2(source_dir / filename, cache_dir / out_filename)
# Out:
# ['QM23.50.001.CX.44.01.01.02', 'QM23.50.001.CX.44.01.07.02', 'QM23.50.001.CX.44.01.03.02', 'QM23.50.001.CX.44.01.05.03', 'QM23.50.001.CX.44.01.09.02']
# ['QM23.50.001.CX.44.02.07.03', 'QM23.50.001.CX.44.02.05.03', 'QM23.50.001.CX.44.02.01.03', 'QM23.50.001.CX.44.02.09.02', 'QM23.50.001.CX.44.02.03.02']
# ['QM23.50.001.CX.44.03.07.02', 'QM23.50.001.CX.44.03.01.03', 'QM23.50.001.CX.44.03.05.02', 'QM23.50.001.CX.44.03.09.02', 'QM23.50.001.CX.44.03.03.02']
# ['QM23.50.001.CX.44.04.05.03', 'QM23.50.001.CX.44.04.03.03', 'QM23.50.001.CX.44.04.01.03', 'QM23.50.001.CX.44.04.09.02', 'QM23.50.001.CX.44.04.05.01', 'QM23.50.001.CX.44.04.03.01', 'QM23.50.001.CX.44.04.07.02', 'QM23.50.001.CX.44.04.05.02']

# %%
cx44_ = ['QM23.50.001.CX.44.01.05.02', 'QM23.50.001.CX.44.02.05.03', 'QM23.50.001.CX.44.03.05.02', 'QM23.50.001.CX.44.04.05.03']
cx44_barcodes = [specimen_barcode_dict[name] for name in cx44_]
cx44_barcodes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/mike.huang/workspace/hmba_image_viewer/sandbox/lims_queries/specimen_related_lims_queries.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226962732d73636f7474642d7578312e636f72702e616c6c656e696e737469747574652e6f7267222c2275736572223a226d696b652e6875616e67227d/home/mike.huang/workspace/hmba_image_viewer/sandbox/lims_queries/specimen_related_lims_queries.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> cx44_ = ['QM23.50.001.CX.44.01.05.02', 'QM23.50.001.CX.44.02.05.03', 'QM23.50.001.CX.44.03.05.02', 'QM23.50.001.CX.44.04.05.03']
# ...

# %%
specimen_barcode_dict['QM23.50.001.CX.44.04.03.03']
# Out:
# '1291813702'

# %%
barcode = 1291813725
query = '''
        select sp.id as specimen_id,
        sp.name as specimen_name,
        sp.barcode as barcode
        from specimens sp
        where sp.barcode = '%s'
        ''' % barcode
res = pd.read_sql(query,con=engine)
len(res)
# Out:
# 0

# %%
id = 1291810548
query = '''
        select sp.id as specimen_id,
        sp.name as specimen_name,
        sp.barcode as barcode
        from specimens sp
        where sp.id = '%s'
        ''' % id
res = pd.read_sql(query,con=engine)
res
# Out:
#    specimen_id               specimen_name     barcode
# 0   1291810548  QM23.50.001.CX.42.02.07.02  1291810548

# %%
# query the donor metadata
donor_name = 'Q21.26.005'
query = '''
    select 
    d.id as donor_id,
    d.name as donor_name,
    tax.name as species,
    sex.name as sex,
    age.name as age_at_death
    from donors d
    left join organisms tax on d.organism_id = tax.id
    left join genders sex on d.gender_id = sex.id
    left join ages age on d.age_id = age.id
    where d.name = '%s'
''' % donor_name

res = pd.read_sql(query,con=engine)
res
# Out:
#      donor_id  donor_name            species sex age_at_death
# 0  1082751941  Q21.26.005  Macaca nemestrina   F        5 yrs

# %%
# query all specimen belonging to donor
donor_name = 'Q21.26.005'
query = '''
    select
    sp.id as specimen_id,
    sp.name as specimen_name,
    d.id as donor_id,
    p.name as project_name,
    plane.name as plane_of_section,
    h.name as hemisphere,
    parent.id as parent_specimen_id,
    parent.name as parent_specimen_name,
    sp.parent_x_coord,
    sp.parent_y_coord,
    sp.parent_z_coord
    from specimens sp
    left join donors d on sp.donor_id = d.id
    left join plane_of_sections plane on sp.plane_of_section_id = plane.id
    left join hemispheres h on sp.hemisphere_id = h.id
    left join specimens parent on sp.parent_id = parent.id
    left join projects p on sp.project_id = p.id
    where d.name = '%s'
''' % donor_name

res = pd.read_sql_query(query,con=engine,dtype={'parent_specimen_id':'Int64',
                                                'parent_x_coord':'Int16',
                                                'parent_y_coord':'Int16',
                                                'parent_z_coord':'Int16',})
res
# Out:
#     specimen_id                 specimen_name    donor_id  \
# 0    1195046987        QM21.26.005.PN.001.002  1082751941
# 1    1194914276        QM21.26.005.PN.001.001  1082751941
# 2    1193189174  QM21.26.005.CX08.ETH.001.002  1082751941
# 3    1193188649  QM21.26.005.CX08.ETH.001.001  1082751941
# 4    1249146873     Q21.26.005.CX.07.02.09.03  1082751941
# ..          ...                           ...         ...
# 91   1082752954              Q21.26.005.12.05  1082751941
# 92   1082752889              Q21.26.005.12.04  1082751941
# 93   1082752815              Q21.26.005.12.03  1082751941
# 94   1082752594                 Q21.26.005.12  1082751941
# 95   1082752228                    Q21.26.005  1082751941
#
#                                    project_name plane_of_section hemisphere  \
# 0   Human in vitro Single Cell Characterization         variable       None
# 1   Human in vitro Single Cell Characterization         variable       None
# ...

# %%
# all possible specimen types
query = '''
    select *
    from specimen_types
''' 
res = pd.read_sql_query(query,con=engine)
res
# Out:
#             id                                        name  \
# 0            1                            Microarray brain
# 1            2                             Microarray slab
# 2            3                            Microarray block
# 3            4                                          CX
# 4            5                                          CB
# ..         ...                                         ...
# 71   309840200  Anatomic Structures ISH for Enriched Genes
# 72  1229959362                                        Slab
# 73  1229959363                                       Block
# 74  1229959364                                     Section
# 75  1229959361                                       Brain
#
#                    created_at                 updated_at
# 0  2011-12-02 19:00:11.842003                        NaT
# 1  2011-12-02 19:00:11.842003                        NaT
# 2  2011-12-02 19:00:11.842003                        NaT
# ...

# %%
# get specimen types
donor_name = 'Q21.26.005'
query = '''
    select
    sp.id as specimen_id,
    sp.name as specimen_name,
    st.name as specimen_type_name
    from specimens sp
    join donors d on sp.donor_id = d.id
    join specimen_types_specimens sts on sts.specimen_id = sp.id
    join specimen_types st on sts.specimen_type_id = st.id
    where d.name = '%s'
''' % donor_name

res = pd.read_sql_query(query,con=engine)
res
# Out:
#     specimen_id                 specimen_name specimen_type_name
# 0    1195046987        QM21.26.005.PN.001.002            Nucleus
# 1    1194914276        QM21.26.005.PN.001.001            Nucleus
# 2    1193189174  QM21.26.005.CX08.ETH.001.002            Nucleus
# 3    1193188649  QM21.26.005.CX08.ETH.001.001            Nucleus
# 4    1249146873     Q21.26.005.CX.07.02.09.03            Section
# 5    1249146866     Q21.26.005.CX.07.02.09.02            Section
# 6    1249146858     Q21.26.005.CX.07.02.09.01            Section
# 7    1249146696     Q21.26.005.CX.07.02.07.03            Section
# 8    1249146688     Q21.26.005.CX.07.02.07.02            Section
# 9    1249146681     Q21.26.005.CX.07.02.07.01            Section
# 10   1249146606     Q21.26.005.CX.07.02.05.03            Section
# 11   1249146592     Q21.26.005.CX.07.02.05.01            Section
# 12   1249146599     Q21.26.005.CX.07.02.05.02            Section
# ...

# %%
# close the connection
engine.dispose()
